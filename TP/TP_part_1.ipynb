# %% [markdown]
# In this practical training, we are going to demonstrate SHG by using a microscopic model of a driven electron by an incident light.
# We will study the linear case and the non linear case by playing with harmonicity or anharmonicity of the oscillator.

# %%
#First, we have to import the python librairies that will be used
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Now, we have to define several functions that will be used:
# -rk_step to solve the differential equations numerically by fourth-order Runge -Kutta method
# -force that will be the equation of motion of your electron
# -run_fft_analysis to run the fft analysis

# %%
# FFT algortihm
def run_fft_analysis(x, t, dt):
    """
    FFT ANALYSIS
    ============
    """
    # Perform FFT

    # Frequency axis

    
    # Take only positive frequencies

    # multiply by 2 (single-sided spectrum)
    
    # Time-domain signal

    
    # Frequency-domain (FFT)
    # Plot the x times 2 pi

# %%
# RK4 algorithm

# %%
# Equation of motion

# %% [markdown]
# Now, you need to propagate your electron depending on initial conditions, then run the run_fft_analysis function to plot the time-domain signal and fresuency-domain signal.
# You will need several variables :
# -A,B and C: the parameters of the oscillator (A=B=0 and C=1 for linear case; A=B=1 and C=-2 for non linearity)
# -x0, v0, E0 and OMEGA0 that are the initial conditions (you can choose E0, OMEGA0 = 0.1, 1 to compare with other students)
# -dt: the timestep
# -Nsteps: the number of steps

# %% [markdown]
# In the case of the anharmonic oscillator, what can you say about the symmetry of the potential ?
# Furthermore, what are the equilibrium position and their respective stability ?

# %%
# Write your code here

# %% [markdown]
# What can you say about the signal in the frequency domain in the linear case and non linear case ? Can you identify the pics ?
